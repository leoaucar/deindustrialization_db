# %%
import requests
import json

r = requests.get("https://servicodados.ibge.gov.br/api/v3/agregados/5938/periodos/2002|2003|2004|2005|2006|2007|2008|2009|2010|2011|2012|2013|2014|2015|2016|2017|2018|2019|2020|2021/variaveis/37|520?localidades=N6[N3[33]]")
# Out:
# [{'id': '37', 'variavel': 'Produto Interno Bruto a preços correntes', 'unidade': 'Mil Reais', 'resultados': [{'classificacoes': [], 'series': [{'localidade': {'id': '3300100', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Angra dos Reis - RJ'}, 'serie': {'2002': '2296837', '2003': '2223041', '2004': '3229372', '2005': '3603919', '2006': '4008492', '2007': '4916765', '2008': '5499406', '2009': '5794724', '2010': '6331318', '2011': '6786692', '2012': '6722197', '2013': '6378172', '2014': '7756628', '2015': '7600989', '2016': '9294025', '2017': '10106295', '2018': '8942168', '2019': '9828660', '2020': '10397760', '2021': '11194244'}}, {'localidade': {'id': '3300159', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Aperibé - RJ'}, 'serie': {'2002': '59466', '2003': '66750', '2004': '46443', '2005': '49246', '2006': '52936', '2007': '55527', '2008': '71203', '2009': '80440', '2010': '93788', '2011': '106596', '2012': '113862', '2013': '134907', '2014': '142621', '2015': '15672
# ...

# %%
#extrair variavel

#extrair localidade

#extrar series
r.json()[0]['resultados'][0]['series'][0]['serie']
# Out:
# {'2002': '2296837',
#  '2003': '2223041',
#  '2004': '3229372',
#  '2005': '3603919',
#  '2006': '4008492',
#  '2007': '4916765',
#  '2008': '5499406',
#  '2009': '5794724',
#  '2010': '6331318',
#  '2011': '6786692',
#  '2012': '6722197',
#  '2013': '6378172',
#  '2014': '7756628',
#  '2015': '7600989',
#  '2016': '9294025',
#  '2017': '10106295',
#  '2018': '8942168',
#  '2019': '9828660',
#  '2020': '10397760',
#  '2021': '11194244'}

# %%
import pprint
pprint.pprint(r.json())
# Out:
# [{'id': '37',
#   'resultados': [{'classificacoes': [],
#                   'series': [{'localidade': {'id': '3300100',
#                                              'nivel': {'id': 'N6',
#                                                        'nome': 'Município'},
#                                              'nome': 'Angra dos Reis - RJ'},
#                               'serie': {'2002': '2296837',
#                                         '2003': '2223041',
#                                         '2004': '3229372',
#                                         '2005': '3603919',
#                                         '2006': '4008492',
#                                         '2007': '4916765',
#                                         '2008': '5499406',
#                                         '2009': '5794724',
#                                         '2010': '6331318',
#                                         '2011': '6786692',
# ...
